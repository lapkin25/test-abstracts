# %% [markdown]
# # Исчисление высказываний - 2
#
# ## Свойства исчисления высказываний
#
# ### Корректность
#
# ### Непротиворечивость
#
# ### Полнота
#
# ### Разрешимость

# %% [markdown]
# ## Вопросы к коллоквиуму по теме
#
# <small>
#
# 1. Выведите формулу замены импликации 𝑥 Ñ 𝑦  𝑥 _ 𝑦 в исчислении высказываний.
# 2. Выведите закон контрапозиции 𝑥 Ñ 𝑦  𝑦 Ñ 𝑥 в исчислении высказываний.
# 3. Выведите закон коммутативности конъюнкции 𝑥 & 𝑦  𝑦 & 𝑥 в исчислении высказываний.
# 4. Выведите закон коммутативности дизъюнкции 𝑥 _ 𝑦  𝑦 _ 𝑥 в исчислении высказываний.
# 5. Выведите закон де Моргана p𝑥 & 𝑦q  𝑥 _ 𝑦 в исчислении высказываний.
# 6. Выведите закон де Моргана p𝑥 _ 𝑦q  𝑥 & 𝑦 в исчислении высказываний.
# 7. Выведите закон ассоциативности конъюнкции p𝑥&𝑦q&𝑧  𝑥&p𝑦&𝑧q в исчислении
# высказываний.
# 8. Выведите закон ассоциативности дизъюнкции p𝑥_𝑦q_𝑧  𝑥_p𝑦_𝑧q в исчислении
# высказываний.
# 9. Выведите первый закон дистрибутивности 𝑥&p𝑦_𝑧q  p𝑥&𝑦q_p𝑥&𝑧q в исчислении
# высказываний.
# 10. Выведите второй закон дистрибутивности 𝑥_p𝑦&𝑧q  p𝑥_𝑦q&p𝑥_𝑧q в исчислении
# высказываний.
# 11. Выведите закон поглощения 𝑥 _ p𝑥 & 𝑦q  𝑥 в исчислении высказываний.
# 12. Выведите закон поглощения 𝑥 & p𝑥 _ 𝑦q  𝑥 в исчислении высказываний.
# 13. Выведите закон склеивания p𝑥 & 𝑦q _ p𝑥 & 𝑦q  𝑥 в исчислении высказываний.
# 14. Выведите закон склеивания p𝑥 _ 𝑦q & p𝑥 _ 𝑦q  𝑥 в исчислении высказываний.
# 15. Выведите закон сокращения 𝑥 _ p 𝑥 & 𝑦q  𝑥 _ 𝑦 в исчислении высказываний.
# 16. Выведите закон сокращения 𝑥 & p 𝑥 _ 𝑦q  𝑥 & 𝑦 в исчислении высказываний.
#
# </small>
